# %%
from manim import *
# Out:
# Manim Community v0.16.0.post0

# %%
# %%manim -v WARNING --disable_caching -qh Thumbnail
#
# class Thumbnail(Scene):
#     def construct(self):
#         line = NumberLine(
#             x_range=[-19, 19, 1],
#             length=30,
#             color=BLUE,
#             include_numbers=True,
#             label_direction=UP,
#         )
#
#         line.move_to(DOWN*2.5)
#         line.scale(1.5)
#
#         plane1 = Rectangle(color = BLUE_C, height = 2.5, width = 2.5, fill_opacity = 1)
#         dot1 = Dot(stroke_width=7, color = BLACK)
#         circle1 = Circle( color = RED, stroke_width=5, radius=0.6)
#         group1 = VGroup(plane1, dot1, circle1)
#         group1.move_to(UP*2.5)
#
#         ###그룹화 시켜서 텍스트를 for문으로 작성
#
#         t1 = MathTex('3')
#         t2 = MathTex('2')
#         plus = MathTex('+')
#         equal = MathTex('=')
#         t5 = MathTex('5')
#
#         group2 = VGroup(t1, plus, t2, equal, t5)
#         for ob in group2:
#             ob.scale(3)
#             ob.set_color(BLUE_C)
#         group2.arrange()
#
#
#         k1 = ValueTracker(5)
#         dot2 = always_redraw(lambda :
#             Dot(stroke_width=25, color = RED, point = line.n2p(k1.get_value()))
#         )
#
#         t11 = MathTex('5')
#         t22 = MathTex('6')
#         minus = MathTex('-')
#         equal1 = MathTex('=')
#         t55 = MathTex('-1')
#
#         group3 = VGroup(t11, minus, t22, equal1, t55)
#         for ob in group3:
#             ob.scale(3)
#             ob.set_color(BLUE_C)
#         group3.arrange()
#
#         a = MathTex(r'a')
#         a.scale(3)
#         a.set_color(RED_C)
#         a.next_to(group1, RIGHT)
#
#         b = a.copy()
#
#         aa = MathTex(r'a^0')
#         aa.scale(3)
#         aa.set_color(RED_C)
#         aa.next_to(group1, RIGHT)
#
#         aaa = MathTex(r'a^5')
#         aaa.scale(3)
#         aaa.set_color(RED_C)
#         aaa.next_to(group1, RIGHT)
#
#         aaaa = MathTex(r'a^{-6}')
#         aaaa.scale(3)
#         aaaa.set_color(RED_C)
#         aaaa.next_to(group1, RIGHT)
#
#         aaaaa = MathTex(r'a^2')
#         aaaaa.scale(3)
#         aaaaa.set_color(RED_C)
#         aaaaa.next_to(group1, RIGHT)
#
#
#         a5 = MathTex(r'a^5')
#
#         a_6 = MathTex(r'a^{-6}}')
#
#         a_equal = MathTex('=')
#
#         at = MathTex(r'a^{5-6}')
#
#         a_1 = MathTex(r'a^{-1}')
#         a_1.scale(3)
#         a_1.set_color(RED_C)
#
#
#         groupa = VGroup(a5,a_6,a_equal, at)
#         for ob in groupa:
#             ob.scale(3)
#             ob.set_color(RED_C)
#
#         groupa.arrange()
#         a_equal.move_to(DOWN*0.3+RIGHT*0.2)
#
#         a_1.move_to(at)
#
#
#
#
#         text1 = Tex('일반인도')
#         text1.move_to(UP*2.8+RIGHT*4)
#         text1.scale(2.5)
#         text1.set_color(BLUE)
#
#         text2 = Tex('이해하는')
#         text2.next_to(text1, DOWN , buff = 0.7)
#         text2.scale(2.5)
#
#         text3 = Tex('위상수학')
#         text3.next_to(text2, DOWN , buff = 0.7)
#         text3.scale(2.5)
#         text3.set_color(BLUE)
#
#
#
#
#
#         group1.move_to(LEFT*3+UP*2)
#         group2.move_to(LEFT*3)
#         self.add(group1, group2, line, dot2, text1, text2, text3)
# Out:
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\9205f16853a267e8.svg contains a reference to id #g2-27, which is not recognized
#   warnings.warn(warning_text)
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\9205f16853a267e8.svg contains a reference to id #g2-115, which is not recognized
#   warnings.warn(warning_text)
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\9205f16853a267e8.svg contains a reference to id #g2-13, which is not recognized
#   warnings.warn(warning_text)
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\9205f16853a267e8.svg contains a reference to id #g2-19, which is not recognized
#   warnings.warn(warning_text)
# ...

# %%
# %%manim -v WARNING --disable_caching -qh Quote
#
# class Quote(Scene):
#     def construct(self):
#         t1 = Tex('수학의 본질은')
#         t1.scale(1.2)
#         t1.move_to(UP + LEFT)
#         t1.set_color(BLUE_C)
#
#         t2 = Tex('그 자유로움에 있다.')
#         t2.scale(1.2)
#
#         t3 = Tex('게오르그 칸토어')
#         t3.scale(1.2)
#         t3.move_to(DOWN + RIGHT)
#         t3.set_color(BLUE_C)
#
#
#         self.play(Write(t1), Write(t2), lag_ratio = 0.5)
#
#         self.wait(0.5)
#         self.play(Write(t3))
#         self.wait()
# Out:
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\c3df4f20d021b294.svg contains a reference to id #g3-134, which is not recognized
#   warnings.warn(warning_text)
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\c3df4f20d021b294.svg contains a reference to id #g6-114, which is not recognized
#   warnings.warn(warning_text)
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\c3df4f20d021b294.svg contains a reference to id #g6-145, which is not recognized
#   warnings.warn(warning_text)
# c:\Users\untea\youtube\lib\site-packages\manim\mobject\svg\svg_mobject.py:345: UserWarning: media\Tex\c3df4f20d021b294.svg contains a reference to id #g4-198, which is not recognized
#   warnings.warn(warning_text)
# ...

# %%
# %%manim -v WARNING --disable_caching -qh Test
#
# class Test(Scene):
#     def construct(self):
#         plane = NumberPlane()
#
#
#         alft = CurvedArrow(2*RIGHT, 2*UP, angle=PI/4, color=BLUE)
#         alft2 =
#         self.add(alft)

# %%
# %%manim -v WARNING --disable_caching -qh Scene1_LinePathConnected
#
# class Scene1_LinePathConnected(Scene):
#     def construct(self):
#
#         plane = NumberPlane()
#         line1 = Line(start=[-10,2,0], end = [10,2,0], color = BLUE, stroke_width = 10)
#
#
#         line2 = Line(start=[-10,-2,0], end = [10,-2,0], color = BLUE, stroke_width = 10)
#
#
#         dot = Dot(point = [0,-2,0], color = BLACK, stroke_width = 10)
#
#         t = ValueTracker(-5)
#
#         dot1 = always_redraw(lambda :
#                 Dot(point=[t.get_value(),2,0], color = RED, stroke_width=10)
#         )
#
#         s = ValueTracker(-5)
#
#         dot2 = always_redraw(lambda :
#                 Dot(point=[s.get_value(),-2,0], color = RED, stroke_width=10)
#         )
#
#
#         self.wait()
#         self.play(Create(line1), Create(line2))
#         self.wait()
#         self.play(Create(dot))
#         self.wait()
#         self.play(Create(dot1))
#         self.wait()
#         self.play(t.animate.set_value(2))
#         self.wait()
#         self.play(t.animate.set_value(-1))
#         self.wait()
#         self.play(t.animate.set_value(6))
#         self.wait()
#         self.play(Create(dot2))
#         self.wait()
#         self.play(s.animate.set_value(-1))
#         self.wait()
#         self.play(s.animate.set_value(-0.1))
#         self.wait()
#         self.play(s.animate.set_value(-6))
#         self.wait()
#         self.play(s.animate.set_value(-0.1))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene1_LinePathConnected@2023-03-23@17-53-09.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene2_PlanePathConnected
#
# class Scene2_PlanePathConnected(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         plane.add_coordinates()
#
#         plane1 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#         plane1.move_to(LEFT*3.5)
#
#         plane2 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#         plane2.move_to(RIGHT*3.5)
#
#         dot = Dot(stroke_width=7, color = BLACK)
#         dot.move_to(RIGHT*3.5)
#
#
#         # t = ValueTracker(-5)
#
#         # dot1 = always_redraw(lambda :
#         #         Dot(point=[t.get_value(),2,0], color = RED, stroke_width=10)
#         # )
#
#         # s = ValueTracker(5)
#
#         # dot2 = always_redraw(lambda :
#         #         Dot(point=[s.get_value(),-2,0], color = RED, stroke_width=10)
#         # )
#
#         dot1 = Dot(point=[-5,2,0], color = RED, stroke_width=10)
#
#         dot2 = Dot(point=[5,2,0], color = RED, stroke_width=10)
#
#         path1 = Polygon([-5,2,0], [-2,1,0], [-4,0.6,0], [-2,-1.5,0])
#
#         path2 = Polygon([5,2,0], [2,2,0], [2,-1,0], [4.5,-2,0],[4.5,1,0],[5,2,0])
#
#
#         self.add(plane1, plane2, dot, dot1, dot2)
#         self.play(MoveAlongPath(dot1, path1), run_time = 4)
#         self.wait()
#         self.play(MoveAlongPath(dot2, path2), run_time = 4)
# Out:
# <video src="media\jupyter\Scene2_PlanePathConnected@2023-03-23@17-53-17.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene3_PlaneandLine
#
# class Scene3_PlaneandLine(Scene):
#
#     def construct(self):
#
#         t = ValueTracker(0.05)
#
#         # plane1 = Rectangle(color = BLUE_C, height = t.get_value(), width = 5, fill_opacity = 1)
#         # plane1.move_to(LEFT*3.5)
#
#         plane1 = always_redraw(lambda :
#                 Rectangle(color = BLUE_C, height = t.get_value(), width = 5, fill_opacity = 1)
#
#         )
#
#
#
#         dot = Dot(stroke_width=7, color = RED)
#
#         s = ValueTracker(0.1)
#
#         circle = always_redraw(lambda :
#                 Circle(radius=s.get_value())
#         )
#
#
#
#
#         self.wait()
#         self.play(Write(plane1))
#         self.wait()
#         self.play(t.animate.set_value(5))
#         self.wait()
#         self.play(Write(circle), Write(dot), run_time = 0.3)
#         self.wait()
#         self.play(s.animate.set_value(1.5), FadeOut(dot))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene3_PlaneandLine@2023-03-23@17-53-25.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene4_PlaneandCircle
#
# class Scene4_PlaneandCircle(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         plane.add_coordinates()
#
#         plane1 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#         plane1.move_to(LEFT*3.5)
#
#         plane2 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#         plane2.move_to(RIGHT*3.5)
#
#         dot = Dot(stroke_width=7, color = BLACK)
#         dot.move_to(RIGHT*3.5)
#
#
#         t1 = ValueTracker(0.6)  #0.065
#
#         circle1_1 = always_redraw(lambda :
#                 Circle(arc_center=[-4,1,0], color = RED, stroke_width=12, radius=t1.get_value())
#         )
#
#         circle1_2 = always_redraw(lambda :
#                 Circle(arc_center=[-4,-1,0], color = RED, stroke_width=12, radius=t1.get_value())
#         )
#
#         circle1_3 = always_redraw(lambda :
#                 Circle(arc_center=[-3,-1.5,0], color = RED, stroke_width=12, radius=t1.get_value())
#         )
#
#         circle1_4 = always_redraw(lambda :
#                 Circle(arc_center=[-2,1.5,0], color = RED, stroke_width=12, radius=t1.get_value())
#         )
#
#         s1 = ValueTracker(0.6)
#
#         circle2_1 = always_redraw(lambda :
#                 Circle(arc_center=[4,1,0], color = RED, stroke_width=12, radius=s1.get_value())
#         )
#
#         circle2_2 = always_redraw(lambda :
#                 Circle(arc_center=[2,1.5,0], color = RED, stroke_width=12, radius=s1.get_value())
#         )
#
#         circle2_3 = always_redraw(lambda :
#                 Circle(arc_center=[4,-1.5,0], color = RED, stroke_width=12, radius=s1.get_value())
#         )
#
#         circle2_4 = always_redraw(lambda :
#                 Circle(arc_center=[3.5,-0.1,0], color = RED, stroke_width=12, radius=s1.get_value())
#         )
#
#
#
#
#         self.add(plane1, plane2, dot)
#         self.wait()
#         self.play(Write(circle1_1), Write(circle2_1))
#         self.wait()
#         self.play(t1.animate.set_value(0.065))
#         self.wait()
#         self.play(FadeOut(circle1_1))
#         t1.set_value(0.6)
#         self.wait()
#         self.play(s1.animate.set_value(0.065))
#         self.wait()
#         self.play(FadeOut(circle2_1))
#         s1.set_value(0.6)
#         self.wait()
#         self.play(Write(circle1_2))
#         self.wait()
#         self.play(t1.animate.set_value(0.065))
#         self.play(FadeOut(circle1_2))
#         t1.set_value(0.6)
#         self.wait()
#         self.play(Write(circle1_3))
#         self.wait()
#         self.play(t1.animate.set_value(0.065))
#         self.play(FadeOut(circle1_3))
#         t1.set_value(0.6)
#         self.wait()
#         self.play(Write(circle1_4))
#         self.wait()
#         self.play(t1.animate.set_value(0.065))
#         self.play(FadeOut(circle1_4))
#         t1.set_value(0.6)
#         self.wait()
#         self.play(Write(circle2_2))
#         self.wait()
#         self.play(s1.animate.set_value(0.065))
#         self.play(FadeOut(circle2_2))
#         s1.set_value(0.6)
#         self.wait()
#         self.play(Write(circle2_3))
#         self.wait()
#         self.play(s1.animate.set_value(0.065))
#         self.play(FadeOut(circle2_3))
#         s1.set_value(0.6)
#         self.wait()
#         self.play(Write(circle2_4))
#         self.wait()
#         self.play(s1.animate.set_value(0.3))
#         self.wait()
#         self.play(s1.animate.set_value(1))
#         self.wait()
#         self.play(s1.animate.set_value(0.3))
#         self.wait()
#         self.play(s1.animate.set_value(0.6))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene4_PlaneandCircle@2023-03-23@17-54-08.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene5_FundamentalGroup1
#
# class Scene5_FundamentalGroup1(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         plane.add_coordinates()
#
#         plane1 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#
#         t = ValueTracker(1)  #0.065
#
#         circle = always_redraw(lambda :
#                 Circle( color = RED, stroke_width=5, radius=t.get_value())
#         )
#
#         s = ValueTracker(0.5)
#         circle1 = always_redraw(lambda :
#                 Circle(arc_center=[s.get_value(), s.get_value(),0],color = PINK, stroke_width=5, radius=1)
#         )
#
#
#         dot = Dot(stroke_width=7, color = BLACK)
#
#         # self.add(plane1, dot, circle, circle1)
#         # self.play(s.animate.set_value(0))
#
#         self.add(plane1, dot)
#         self.wait()
#         self.play(Write(circle))
#         self.wait()
#         self.play(Write(circle1))
#         self.wait()
#         self.play(s.animate.set_value(0))
#         self.wait()
#         self.play(FadeOut(circle1))
#         self.wait()
#         self.play(t.animate.set_value(2))
#         self.wait()
#         self.play(t.animate.set_value(0.5))
#         self.wait()
#         self.play(t.animate.set_value(1))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene5_FundamentalGroup1@2023-03-23@17-54-21.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene6_FundamentalGroup2
#
# class Scene6_FundamentalGroup2(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         plane.add_coordinates()
#
#         dot = Dot(stroke_width=7, color = BLACK)
#
#         plane1 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#
#         circle = Circle( color = RED, stroke_width=5, radius=1)
#
#         # alft = CurvedArrow(2*RIGHT, 2*UP, angle=PI/4, color=BLUE)
#
#         t = ValueTracker(0)
#
#         aa = always_redraw(lambda :
#
#                     Dot(
#                     point = [np.cos(t.get_value()), np.sin(t.get_value()),0],
#                     color=PINK,
#                     radius = 0.2
#                     )
#         )
#
#         s = ValueTracker(0)
#
#         bb = always_redraw(lambda :
#
#                     Dot(
#                     point = [np.cos((-1)*s.get_value()), np.sin((-1)*s.get_value()),0],
#                     color=PINK,
#                     radius = 0.2
#                     )
#         )
#
#
#         x = 0
#         t0 = MathTex(str(x))
#         t0.move_to(plane.c2p(1.5,1.5))
#         t0.scale(2)
#         t0.set_color(PINK)
#
#
#
#         self.add(plane1, circle, dot, aa, t0)
#         self.wait()
#         x = 1
#         t1 = MathTex(str(x))
#         t1.move_to(plane.c2p(1.5,1.5))
#         t1.scale(2)
#         t1.set_color(PINK)
#         self.play(Transform(t0,t1), t.animate.set_value(2*PI))
#         self.wait()
#         t.set_value(0)
#         x = 2
#         t2 = MathTex(str(x))
#         t2.move_to(plane.c2p(1.5,1.5))
#         t2.scale(2)
#         t2.set_color(PINK)
#         self.play(Transform(t0,t2), t.animate.set_value(2*PI))
#         self.wait()
#         t.set_value(0)
#         x = 3
#         t3 = MathTex(str(x))
#         t3.move_to(plane.c2p(1.5,1.5))
#         t3.scale(2)
#         t3.set_color(PINK)
#         self.play(Transform(t0,t3), t.animate.set_value(2*PI))
#         self.add(bb)
#         self.play(FadeOut(aa))
#         self.wait()
#         x = 2
#         t4 = MathTex(str(x))
#         t4.move_to(plane.c2p(1.5,1.5))
#         t4.scale(2)
#         t4.set_color(PINK)
#         self.play(Transform(t0,t4), s.animate.set_value(2*PI))
#         self.wait()
#         s.set_value(0)
#         x = 1
#         t5 = MathTex(str(x))
#         t5.move_to(plane.c2p(1.5,1.5))
#         t5.scale(2)
#         t5.set_color(PINK)
#         self.play(Transform(t0,t5), s.animate.set_value(2*PI))
#         self.wait()
#         s.set_value(0)
#         x = 0
#         t5 = MathTex(str(x))
#         t5.move_to(plane.c2p(1.5,1.5))
#         t5.scale(2)
#         t5.set_color(PINK)
#         self.play(Transform(t0,t5), s.animate.set_value(2*PI))
#         self.wait()
#         s.set_value(0)
#         x = -1
#         t6 = MathTex(str(x))
#         t6.move_to(plane.c2p(1.5,1.5))
#         t6.scale(2)
#         t6.set_color(PINK)
#         self.play(Transform(t0,t6), s.animate.set_value(2*PI))
#         self.wait()
#         s.set_value(0)
#         x = -2
#         t6 = MathTex(str(x))
#         t6.move_to(plane.c2p(1.5,1.5))
#         t6.scale(2)
#         t6.set_color(PINK)
#         self.play(Transform(t0,t6), s.animate.set_value(2*PI))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene6_FundamentalGroup2@2023-03-23@17-54-37.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene7_3DScene
#
# class Scene7_3DScene(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes()
#
#         # graph = axes.get_parametric_curve(lambda t:
#         # np.array([
#         #         np.cos(t),
#         #         np.sin(t),
#         #         t/(2*PI)
#         # ])
#         # # t_range = (-2*PI, 2*PI, 0.01),
#         # # color = PINK
#         # )
#
#         curve1 = ParametricFunction(
#             lambda u: np.array([
#                 np.cos(u),
#                 np.sin(u),
#                 u * (1/(2*PI))
#             ]), color=RED, t_range = np.array([-3*TAU, 5*TAU, 0.01])
#         ).set_shade_in_3d(True)
#
#         x_label = axes.get_x_axis_label(Tex("x"))
#         y_label = axes.get_y_axis_label(Tex("y")).shift(UP * 1.8)
#
#         plane1 = Rectangle(color = BLUE_C, height = 5, width = 5, fill_opacity = 1)
#         dot1 = Dot(stroke_width=7, color = BLACK)
#         circle1 = Circle( color = RED, stroke_width=5, radius=1)
#
#         circle2 = circle1.copy()
#         circle2.set_color(BLUE)
#
#         group0 = Group(plane1, circle1, dot1, curve1)
#
#         group1 = group0.copy()
#         group1.move_to(OUT)
#
#
#         dot = Dot3D()
#
#         k = ValueTracker(0)
#         movingdot1 = always_redraw(lambda :
#                 Dot3D(
#                 point=[np.cos(k.get_value()),
#                 np.sin(k.get_value()),
#                 k.get_value() * (1/(2*PI))],
#
#                 radius = 0.2,
#                 color = YELLOW
#                 )
#         )
#
#         movingdotonplane = always_redraw(lambda :
#                 Dot3D(
#                 point=[np.cos(k.get_value()),
#                 np.sin(k.get_value()),
#                 0],
#
#                 radius = 0.2,
#                 color = PINK
#                 )
#         )
#
#         self.set_camera_orientation(zoom=1.2)
#         self.add(group0, curve1, movingdot1, movingdotonplane)
#         self.wait()
#         self.set_camera_orientation(zoom=0.5)
#
#         self.wait(0.5)
#         self.move_camera(phi=85 * DEGREES, theta=30 * DEGREES, zoom=1, run_time=1.5)
#         self.play(FadeOut(plane1), Transform(circle1, circle2))
#         # self.begin_ambient_camera_rotation(rate=0.15)
#         self.wait()
#         self.play(k.animate.set_value(2*PI))
#         self.wait(1)
#         self.play(k.animate.set_value(4*PI))
#         self.wait(1)
#         self.play(k.animate.set_value(6*PI))
#         self.wait()
#         self.play(k.animate.set_value(4*PI))
#         self.wait()
#         self.play(k.animate.set_value(2*PI))
#         self.wait()
#         self.play(k.animate.set_value(0*PI))
#         self.wait()
#         self.play(k.animate.set_value((-2)*PI))
#         self.wait()
#         self.play(k.animate.set_value((-4)*PI))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene7_3DScene@2023-03-23@17-57-17.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene8_fundamentalgroup
#
# class Scene8_fundamentalgroup(ThreeDScene):
#     def construct(self):
#         line = NumberLine(
#             x_range=[-19, 19, 1],
#             length=30,
#             color=BLUE,
#             include_numbers=True,
#             label_direction=UP,
#         )
#
#         line.move_to(DOWN*2.5)
#         line.scale(1.5)
#
#         plane1 = Rectangle(color = BLUE_C, height = 2.5, width = 2.5, fill_opacity = 1)
#         dot1 = Dot(stroke_width=7, color = BLACK)
#         circle1 = Circle( color = RED, stroke_width=5, radius=0.6)
#         group1 = VGroup(plane1, dot1, circle1)
#         group1.move_to(UP*2.5)
#
#         ###그룹화 시켜서 텍스트를 for문으로 작성
#
#         t1 = MathTex('3')
#         t2 = MathTex('2')
#         plus = MathTex('+')
#         equal = MathTex('=')
#         t5 = MathTex('5')
#
#         group2 = VGroup(t1, plus, t2, equal, t5)
#         for ob in group2:
#             ob.scale(3)
#             ob.set_color(BLUE_C)
#         group2.arrange()
#
#
#         k1 = ValueTracker(3)
#         dot2 = always_redraw(lambda :
#             Dot(stroke_width=25, color = RED, point = line.n2p(k1.get_value()))
#         )
#
#         t11 = MathTex('5')
#         t22 = MathTex('6')
#         minus = MathTex('-')
#         equal1 = MathTex('=')
#         t55 = MathTex('-1')
#
#         group3 = VGroup(t11, minus, t22, equal1, t55)
#         for ob in group3:
#             ob.scale(3)
#             ob.set_color(BLUE_C)
#         group3.arrange()
#
#         a = MathTex(r'a')
#         a.scale(3)
#         a.set_color(RED_C)
#         a.next_to(group1, RIGHT)
#
#         b = a.copy()
#
#         aa = MathTex(r'a^0')
#         aa.scale(3)
#         aa.set_color(RED_C)
#         aa.next_to(group1, RIGHT)
#
#         aaa = MathTex(r'a^5')
#         aaa.scale(3)
#         aaa.set_color(RED_C)
#         aaa.next_to(group1, RIGHT)
#
#         aaaa = MathTex(r'a^{-6}')
#         aaaa.scale(3)
#         aaaa.set_color(RED_C)
#         aaaa.next_to(group1, RIGHT)
#
#         aaaaa = MathTex(r'a^2')
#         aaaaa.scale(3)
#         aaaaa.set_color(RED_C)
#         aaaaa.next_to(group1, RIGHT)
#
#
#         a5 = MathTex(r'a^5')
#
#         a_6 = MathTex(r'a^{-6}}')
#
#         a_equal = MathTex('=')
#
#         at = MathTex(r'a^{5-6}')
#
#         a_1 = MathTex(r'a^{-1}')
#         a_1.scale(3)
#         a_1.set_color(RED_C)
#
#
#         groupa = VGroup(a5,a_6,a_equal, at)
#         for ob in groupa:
#             ob.scale(3)
#             ob.set_color(RED_C)
#
#         groupa.arrange()
#         a_equal.move_to(DOWN*0.3+RIGHT*0.2)
#
#         a_1.move_to(at)
#
#
#
#
#
#
#
#
#         self.wait()
#         self.play(DrawBorderThenFill(group1))
#         self.wait()
#         self.play(Write(line))
#         self.wait()
#         self.play(Write(dot2))
#         self.wait()
#         self.play(k1.animate.set_value(5))
#         self.wait()
#         self.play(Write(group2))
#         self.wait()
#         self.play(k1.animate.set_value(-1))
#         self.wait()
#         self.play(FadeOut(group2))
#         self.wait()
#         self.play(Write(group3))
#         self.wait()
#         self.play(FadeOut(group3))
#         self.wait()
#         self.play(Write(a))
#         self.wait()
#         self.play(Transform(a, aa))
#         self.wait()
#         self.play(Transform(a, aaa))
#         self.wait()
#         self.play(Transform(a, aaaa))
#         self.wait()
#         self.play(Transform(a, aaaaa))
#         self.wait()
#         self.play(Transform(a, b))
#         self.wait()
#         self.play(Write(groupa))
#         self.wait()
#         self.play(Transform(at, a_1))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene8_fundamentalgroup@2023-03-23@17-57-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene9_nailexplaned
#
# class Scene9_nailexplaned(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         plane.add_coordinates()
#
#         plane1 = Rectangle(color = BLUE_C, height = 8, width = 12, fill_opacity = 1)
#
#
#
#
#         nail1 = Dot(stroke_width=15, color = BLACK, point = [3,2,0])
#         nail2 = Dot(stroke_width=15, color = BLACK, point = [-3,2,0])
#
#         s = ValueTracker(2)
#         not1 = always_redraw(lambda :
#                 Circle(arc_center=[3, s.get_value(),0],color = PINK, stroke_width=9, radius=1)
#         )
#
#         t = ValueTracker(1)
#         not2 = always_redraw(lambda :
#                 Circle(arc_center=[3, 2,0],color = PINK, stroke_width=9, radius=t.get_value())
#         )
#
#
#
#         # t = ValueTracker(-5)
#
#         # dot1 = always_redraw(lambda :
#         #         Dot(point=[t.get_value(),2,0], color = RED, stroke_width=10)
#         # )
#
#         # s = ValueTracker(5)
#
#         # dot2 = always_redraw(lambda :
#         #         Dot(point=[s.get_value(),-2,0], color = RED, stroke_width=10)
#         # )
#
#         dot1 = Dot(point=[0,-1,0], color = PURPLE, stroke_width=20)
#
#         dot2 = Dot(point=[0,-1,0], color = GREEN, stroke_width=20)
#
#         generator1 = Polygon([0, -1,0], [-2,3,0], [-4,3,0], [-4,1,0], stroke_width= 7)
#         generator1.set_color(PURPLE)
#
#         generator2 = Polygon([0, -1,0], [2,3,0], [4,3,0], [4,1,0], stroke_width= 7)
#         generator2.set_color(GREEN)
#
#         a = MathTex('a')
#         a.scale(3)
#         a.set_color(PURPLE)
#         a.move_to(plane.c2p(-4, -1, 0))
#
#         b = MathTex('b')
#         b.scale(3)
#         b.set_color(GREEN)
#         b.move_to(plane.c2p(4, -1, 0))
#
#
#
#         self.wait()
#         self.play(Write(plane1))
#         self.wait()
#         self.play(Write(nail1))
#         self.wait()
#         self.play(DrawBorderThenFill(not1))
#         self.wait()
#         self.play(s.animate.set_value(1.3))
#         self.wait()
#         self.play(FadeOut(nail1))
#         self.wait()
#         self.play(s.animate.set_value(-5))
#         self.wait()
#         self.play(s.animate.set_value(2))
#         self.wait()
#         self.play(Write(nail1))
#         self.wait()
#         self.play(FadeOut(not1), FadeIn(not2))
#         self.wait()
#         self.play(t.animate.set_value(0.3))
#         self.wait()
#         self.play(FadeOut(nail1))
#         self.play(t.animate.set_value(0.01))
#         self.wait()
#         self.play(FadeOut(not2))
#         self.wait()
#         self.play(Write(nail1), Write(nail2))
#         self.wait()
#         self.play(Write(generator1), Write(generator2))
#         self.wait()
#         self.play(Write(dot1))
#         self.wait()
#         self.play(MoveAlongPath(dot1, generator1), run_time = 2)
#         self.wait()
#         self.play(MoveAlongPath(dot2, generator2), run_time = 2)
#         self.wait()
#         self.play(Write(a), Write(b))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene9_nailexplaned@2023-03-23@17-58-29.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING --disable_caching -qh Scene10_answer
#
# class Scene10_answer(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         plane.add_coordinates()
#
#         plane1 = Rectangle(color = BLUE_C, height = 8, width = 12, fill_opacity = 1)
#
#
#
#
#         nail1 = Dot(stroke_width=15, color = BLACK, point = [3,2,0])
#         nail2 = Dot(stroke_width=15, color = BLACK, point = [-3,2,0])
#
#         s = ValueTracker(2)
#         not1 = always_redraw(lambda :
#                 Circle(arc_center=[3, s.get_value(),0],color = PINK, stroke_width=9, radius=1)
#         )
#
#         t = ValueTracker(1)
#         not2 = always_redraw(lambda :
#                 Circle(arc_center=[3, 2,0],color = PINK, stroke_width=9, radius=t.get_value())
#         )
#
#
#
#         # t = ValueTracker(-5)
#
#         # dot1 = always_redraw(lambda :
#         #         Dot(point=[t.get_value(),2,0], color = RED, stroke_width=10)
#         # )
#
#         # s = ValueTracker(5)
#
#         # dot2 = always_redraw(lambda :
#         #         Dot(point=[s.get_value(),-2,0], color = RED, stroke_width=10)
#         # )
#
#         dot1 = Dot(point=[0,-1,0], color = PURPLE, stroke_width=20)
#
#         dot2 = Dot(point=[0,-1,0], color = GREEN, stroke_width=20)
#
#         generator1 = Polygon([0, -1,0], [-2,3,0], [-4,3,0], [-4,1,0], stroke_width= 7)
#         generator1.set_color(PURPLE)
#
#         generator2 = Polygon([0, -1,0], [2,3,0], [4,3,0], [4,1,0], stroke_width= 7)
#         generator2.set_color(GREEN)
#
#         aaa = MathTex('a')
#         aaa.scale(3)
#         aaa.set_color(PURPLE)
#         aaa.move_to(plane.c2p(-4, -1, 0))
#
#         bbb = MathTex('b')
#         bbb.scale(3)
#         bbb.set_color(GREEN)
#         bbb.move_to(plane.c2p(4, -1, 0))
#
#         group = VGroup(plane1, nail1, nail2, dot1, dot2, generator1, generator2, aaa, bbb)
#
#         a = MathTex('a')
#         a.set_color(PURPLE)
#         a.scale(3.3)
#
#         a_0 = MathTex('a^0')
#         a_0.set_color(PURPLE)
#         a_0.scale(3.3)
#         a_0.move_to(plane.c2p(0, -2, 0))
#
#         b = MathTex('b')
#         b.set_color(GREEN)
#         b.scale(3)
#
#         group1 = VGroup(a,b)
#         group1.arrange()
#         group1.move_to(plane.c2p(0, -2, 0))
#
#         group11 = group1.copy()
#
#         a_2 = MathTex('a^{-2}')
#         a_2.set_color(PURPLE)
#         a_2.scale(3)
#
#         group2 = VGroup(a,b,a_2)
#         group2.arrange()
#         group2.move_to(plane.c2p(0, -2, 0))
#
#         group22 = group2.copy()
#
#         group3 = VGroup(a_2,a,b)
#         group3.arrange()
#         group3.move_to(plane.c2p(0, -2, 0))
#
#         group33 = group3.copy()
#
#         a_1 = MathTex('a^{-1}')
#         a_1.set_color(PURPLE)
#         a_1.scale(3)
#
#         group4 = VGroup(a_1,b)
#         group4.arrange()
#         group4.move_to(plane.c2p(0, -2, 0))
#
#         group44 = group4.copy()
#
#         group5 = VGroup(a_1, b, a)
#         group5.arrange()
#         group5.move_to(plane.c2p(0, -2, 0))
#
#         group55 = group5.copy()
#
#         group555 = group5.copy()
#
#         fa =  MathTex('a')
#         fa.set_color(PURPLE)
#         fa.scale(3.3)
#
#         fb = MathTex('b')
#         fb.set_color(GREEN)
#         fb.scale(3)
#
#         fa_1 = MathTex('a^{-1}')
#         fa_1.set_color(PURPLE)
#         fa_1.scale(3)
#
#         fb_1 = MathTex('b^{-1}')
#         fb_1.set_color(GREEN)
#         fb_1.scale(3)
#
#         fgroup = VGroup(fa, fb, fa_1, fb_1)
#         fgroup.arrange()
#         fgroup.move_to(plane.c2p(0, -2, 0))
#
#
#
#
#
#
#         self.add(group)
#         self.wait()
#         self.play(group.animate.scale(0.5))
#         self.wait()
#         self.play(group.animate.move_to(UP*1.5))
#         self.wait()
#         self.play(Write(group11))
#         self.wait()
#         self.play(Transform(group11, group22))
#         self.wait()
#         self.play(Transform(group11, group33))
#         self.wait()
#         self.play(Transform(group11, group44))
#         self.wait()
#         self.play(Transform(group11, group55))
#         self.wait()
#         self.play(FadeOut(group11), FadeIn(group555))
#         self.wait()
#         self.play(FadeOut(nail1))
#         self.wait()
#         self.play(FadeOut(generator2))
#         self.wait()
#         self.play(FadeOut(group555[1]))
#         self.wait()
#         self.play(FadeOut(group555[0]), FadeOut(group555[2]), FadeIn(a_0))
#         self.wait()
#         self.play(FadeOut(generator1), FadeOut(dot1), FadeOut(dot2))
#         self.wait()
#         self.play(FadeOut(a_0))
#         self.wait()
#         self.play(Write(generator1), Write(generator2), Write(nail1))
#         self.wait()
#         self.play(Write(fgroup))
#         self.wait()
#         self.play(FadeOut(fgroup[1]), FadeOut(fgroup[3]))
#         self.wait()
#         self.play(FadeIn(fgroup[1]), FadeIn(fgroup[3]))
#         self.wait()
#         self.play(FadeOut(fgroup[0]), FadeOut(fgroup[2]))
#         self.wait()
#         self.play(FadeOut(fgroup[1]), FadeOut(fgroup[3]))
#         self.wait()
# Out:
# <video src="media\jupyter\Scene10_answer@2023-03-23@17-59-07.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
